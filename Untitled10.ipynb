# %% [markdown]
# <a href="https://colab.research.google.com/github/Aneshya/git/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x=[1,6,9,3]
y=[8,4,98,5]
plt.plot(x,y,marker='o',color='blue')
plt.title('Research Graph')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()
